# %% [markdown]
# **Problem Statement :**
#
# **Using Mall Customer Data Set and  performing K-means clustering to segregate customers based on data in form of optimal clusters**

# %% [markdown]
# Process :
#
# 1. Understanding data
# 2. Perform Elbow method to find the No. of clusters
# 3. Training a model using unsupervised learning algorithm(K-Means)
# 4. Plotting the Clusters

# %%
! pip install https://github.com/pandas-profiling/pandas-profiling/archive/master.zip
# Out:
# ...
#      | 17.8 MB 19.8 MB/s 0:00:01
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 381.9/381.9 kB 2.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.7/102.7 kB 7.0 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 679.5/679.5 kB 11.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 14.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 35.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 20.3 MB/s eta 0:00:00
# ...
#   Created wheel for ydata-profiling: filename=ydata_profiling-0.0.dev0-py2.py3-none-any.whl size=357898 sha256=b585d59aba5a2d78e887256f26a871c8282702ef6d8af905f8bd017cb07e4688
#   Stored in directory: /tmp/pip-ephem-wheel-cache-dh25ha_n/wheels/07/29/61/f533cc7cbd0a97efb2d1b94d3254a3e859a949367ba842577b
# ...

# %%
import os
os._exit(00)

# %% [markdown]
# 1. Understanding data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# importing useful and required libraries
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import pandas_profiling
from pandas_profiling import ProfileReport
# Out:
# <ipython-input-2-90f3a18abbb1>:6: DeprecationWarning: `import pandas_profiling` is going to be deprecated by April 1st. Please use `import ydata_profiling` instead.
#   import pandas_profiling

# %%
# Load data
df=pd.read_csv('/content/drive/MyDrive/Nam4_KHTN_HK1/nam4_Seminar/Mall_Customers.csv')

# %%
# Display top 10 rows
df.head(10)
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40
# 5           6  Female   22                  17                      76
# 6           7  Female   35                  18                       6
# 7           8  Female   23                  18                      94
# 8           9    Male   64                  19                       3
# 9          10  Female   30                  19                      72

# %%
df.shape
# Out:
# (200, 5)

# %%
# display Null values , datatype ...
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
df.describe()
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   38.850000           60.560000               50.200000
# std     57.879185   13.969007           26.264721               25.823522
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.750000           41.500000               34.750000
# 50%    100.500000   36.000000           61.500000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %%
# Cho mình thấy được 1 cái over view cho data ( không cần vẽ từng cái ra) ( VD : alert , biểu đồ , dạng histogram , và cái thông số có bị missing hay không , các thống kê về data)
ProfileReport(df)
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v0.0.dev0&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2024-01-02 14:35:20.857833&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
# Preparing data for clustering
# creata data which has values of Annual Income and Spending Score
X = df.iloc[:,[3,4]].

# %%
X
# Out:
# array([[ 15,  39],
#        [ 15,  81],
#        [ 16,   6],
#        [ 16,  77],
#        [ 17,  40],
#        [ 17,  76],
#        [ 18,   6],
#        [ 18,  94],
#        [ 19,   3],
#        [ 19,  72],
#        [ 19,  14],
#        [ 19,  99],
#        [ 20,  15],
#        [ 20,  77],
#        [ 20,  13],
#        [ 20,  79],
#        [ 21,  35],
#        [ 21,  66],
#        [ 23,  29],
#        [ 23,  98],
#        [ 24,  35],
#        [ 24,  73],
#        [ 25,   5],
#        [ 25,  73],
#        [ 28,  14],
#        [ 28,  82],
#        [ 28,  32],
#        [ 28,  61],
#        [ 29,  31],
#        [ 29,  87],
#        [ 30,   4],
#        [ 30,  73],
#        [ 33,   4],
#        [ 33,  92],
#        [ 33,  14],
#        [ 33,  81],
#        [ 34,  17],
#        [ 34,  73],
#        [ 37,  26],
#        [ 37,  75],
#        [ 38,  35],
#        [ 38,  92],
#        [ 39,  36],
#        [ 39,  61],
#        [ 39,  28],
#        [ 39,  65],
#        [ 40,  55],
# ...

# %%
plt.scatter( X[:,0] , X[:,1] , s=10 , c="black")

# %% [markdown]
# 2. Performing elbow method to find  optimal No. of clusters

# %%
# Using K-Means to iterate from 1 to 11 cluster and plotting a elbow plot
from sklearn.cluster import KMeans
wcss = []

# %%
#Using a loop to find the optimal values of k using the elbow method
for i in range(1,11):
  kmeans = KMeans(n_clusters = i , init ='k-means++',random_state = 0)
  kmeans.fit(X)
  wcss.append(kmeans.inertia_)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
# Deciding the optimal number of clusters
plt.plot(range(1,11),wcss)
plt.title('The elbow method')
plt.xlabel('No. of clusters')
plt.ylabel('WCSS values')
plt.show()

# %% [markdown]
# 3. Training model using K-Means

# %%
# Initialize K-Means with the selected optimal No. of clusters( k=5)
kmeansmodel = KMeans(n_clusters = 5 ,init ='k-means++' ,random_state = 0)

# %%
# Use model for prediction
y_kmeans= kmeansmodel.fit_predict(X)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
# Plot all the clusters
plt.scatter(X[y_kmeans == 0,0 ] , X[y_kmeans == 0,1] , s=80 , c='red' ,label ='Customer 1')
plt.scatter(X[y_kmeans == 1,0 ] , X[y_kmeans == 1,1] , s=80 , c='blue' ,label ='Customer 2')
plt.scatter(X[y_kmeans == 2,0 ] , X[y_kmeans == 2,1] , s=80 , c='yellow' ,label ='Customer 3')
plt.scatter(X[y_kmeans == 3,0 ] , X[y_kmeans == 3,1] , s=80 , c='cyan' ,label ='Customer 4')
plt.scatter(X[y_kmeans == 4,0 ] , X[y_kmeans == 4,1] , s=80 , c='black' ,label ='Customer 5')
plt.scatter(kmeans.cluster_centers_[:,0] ,kmeans.cluster_centers_[:,1] ,s=100 , c='magenta', label='Centroids' )
plt.title('Clusters of customers')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score (1-100)')
plt.legend()
plt.show()

# %% [markdown]
# DBSCAN

# %%
from sklearn.cluster import DBSCAN

# %%
dbscan= DBSCAN(eps=5 , min_samples=5)

# %%
labels=dbscan.fit_predict(X)

# %%
np.unique(labels)
# Out:
# array([-1,  0,  1,  2,  3,  4])

# %%
plt.scatter(X[labels == -1,0 ] , X[labels == -1,1] , s=10 , c='black' )
plt.scatter(X[labels == 0,0 ] , X[labels == 0,1] , s=10 , c='red' )
plt.scatter(X[labels == 1,0 ] , X[labels == 1,1] , s=10 , c='yellow' )
plt.scatter(X[labels == 2,0 ] , X[labels == 2,1] , s=10 , c='cyan' )
plt.scatter(X[labels == 3,0 ] , X[labels == 3,1] , s=10 , c='blue' )
plt.scatter(X[labels == 4,0 ] , X[labels== 4,1] , s=10 , c='green' )

plt.title('Clusters of customers')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score (1-100)')
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# **GMM**

# %%
from sklearn.mixture import GaussianMixture

# %%
gmm = GaussianMixture(n_components = 5)

gmm.fit(X)

labels_gmm = gmm.predict(X)

# %%
np.unique(labels_gmm)
# Out:
# array([0, 1, 2, 3, 4])

# %%
plt.scatter(X[labels_gmm == 0,0 ] , X[labels_gmm == 0,1] , s=80 , c='red' ,label ='Customer 1')
plt.scatter(X[labels_gmm == 1,0 ] , X[labels_gmm == 1,1] , s=80 , c='blue' ,label ='Customer 2')
plt.scatter(X[labels_gmm == 2,0 ] , X[labels_gmm == 2,1] , s=80 , c='yellow' ,label ='Customer 3')
plt.scatter(X[labels_gmm == 3,0 ] , X[labels_gmm == 3,1] , s=80 , c='cyan' ,label ='Customer 4')
plt.scatter(X[labels_gmm == 4,0 ] , X[labels_gmm == 4,1] , s=80 , c='green' ,label ='Customer 5')
plt.title('Clusters of customers')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score (1-100)')
plt.legend()
plt.show()
